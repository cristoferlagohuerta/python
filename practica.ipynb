# %%
class Nodo:
    def __init__(self,valor):
        self.valor= valor
        self.derecha= None
        self.izquierda= None

raiz = Nodo ("+")
raiz.izquierda = Nodo ("-") 
raiz.derecha = Nodo ("*") 
raiz.izquierda.izquierda = Nodo ("*")
raiz.izquierda.izquierda.izquierda.izquierda = Nodo ("+")
raiz.izquierda.izquierda.izquierda.izquierda.izquierda = Nodo ("10")
raiz.izquierda.izquierda.izquierda.izquierda.derecha = Nodo ("1")
raiz.izquierda.izquierda.izquierda.derecha = Nodo ("3")
raiz.izquierda.izquierda.derecha = Nodo ("20")
raiz.derecha.izquierda = Nodo ("3")
raiz.derecha.derecha = Nodo ("2")



nodo_10=Nodo (10)
nodo_1=Nodo (1)
nodo_3=Nodo (3)
nodo_20=Nodo (20)
nodo_3_1=Nodo (3)
nodo_2=Nodo (2)

nodo_suma_abajo = Nodo('+')
nodo_suma_abajo.izquierda = Nodo('nodo_10')
nodo_suma_abajo.derecha = Nodo('nodo_1')

nodo_mult_abajo = Nodo('*')
nodo_mult_abajo.derecha = Nodo('nodo_3')

nodo_rest_abajo = Nodo('-')
nodo_suma_abajo.derecha = Nodo('nodo_20')


nodo_suman2_abajo= Nodo ('+')
nodo_suman2_abajo.derecha= Nodo('*')
nodo_suma_abajo.izquierda = Nodo('nodo_3_1')
nodo_suma_abajo.izquierda = Nodo('nodo_2')



def recorrido_inorden(raiz):
    if raiz:
       recorrido_inorden(raiz.izquierda)
       print(raiz.valor, end=' ')
       recorrido_inorden(raiz.derecha)

print("\n RECORRIDO IN-ORDEN")
recorrido_inorden(raiz)
print("\n Resultado: ", (raiz.izquierda.izquierda.valor + raiz.izquierda.derecha.valor) * (raiz.derecha.izquierda.valor - raiz.derecha.derecha.valor))


def recorrido_preorder(raiz):
   if raiz:
      print(raiz.valor, end=' ') 
      recorrido_preorder(raiz.izquierda)
      recorrido_preorder(raiz.derecha)

print("\n RECORRIDO PRE-ORDEN")
recorrido_preorder(raiz)
print("\n Resultado: ", +-*+10 1 3 20 * 3 2)

def recorrido_postorden(raiz):
   if raiz:
        recorrido_postorden(raiz.izquierda)
        recorrido_postorden(raiz.derecha)
        print(raiz.valor, end= ' ')

print("\n RECORRIDO POST-ORDEN")
recorrido_postorden(raiz)
print("\n Resultado: ", 10 1 +3 * 3)
# Out:
#   Cell In[11], line 65
#     print("\n Resultado: ", +-*+10 1 3 20 * 3 2)
#                               ^
# SyntaxError: invalid syntax

# %%
=
