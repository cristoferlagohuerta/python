# %%
#creando un nodo
# un nodo es como una caja
#GUARDA: EL VALOR (NUMERO)
# guarda: dos flechas apuntando a sus hijos


class Nodo:
    def __init__(self, valor):
        self.valor = valor
        self.iz = None  #hijo izquierdo (numero menores)
        self.der= None  #hijo derecho(numero mayores)


# creamos un nodo simple

raiz = Nodo(10)
print (f"el valor del nodo es: {raiz.valor}")
# Out:
# el valor del nodo es: 10

# %%
#creando un nodo
# un nodo es como una caja
#GUARDA: EL VALOR (NUMERO)
# guarda: dos flechas apuntando a sus hijos


class Nodo:
    def __init__(self, valor):
        self.valor = valor
        self.iz = None  #hijo izquierdo (numero menores)
        self.der= None  #hijo derecho(numero mayores)


# creamos un nodo simple

raiz = Nodo(10)
izq= raiz.iz = Nodo(5) # 5 es menor que 10
dere= raiz.der = Nodo(15) #15 es mayor que  10

print (f"el valor del nodo es: {raiz.valor}")
print (f"el valor del nodo izquierdo es: {raiz.iz.valor}")
print (f"el valor del nodo derecho es : {raiz.der.valor}")
# Out:
# el valor del nodo es: 10
# el valor del nodo es: 5
# el valor del nodo es: 15

# %%
### desafio 2:

#crea un arbol  con raiz 20
#hijo iz 10 u derecho 30

class Nodo:
    def __init__(self,valor):
        self.valor= valor
        self.iz = None
        self.der = None

raiz = Nodo(20)
raiz.iz = Nodo(10)
raiz.der = Nodo(30)

print (f"el valor del nodo es: {raiz.valor}")
print (f"el valor del nodo izquierdo es: {raiz.iz.valor}")
print (f"el valor del nodo derecho es : {raiz.der.valor}")
# Out:
# el valor del nodo es: 20
# el valor del nodo izquierdo es: 10
# el valor del nodo derecho es : 30

# %%
##Desafio 3:

# III . insertar valores

#regla:
# si el valor es menor -> ir a la izquierda
# si el valor es mayor -> ir a la derecha
# repetir hasta encontrar un espacio vacio


def insertar(raiz,valor):
    if raiz is None:
        return  Nodo(valor)
    # si el valor es menor
    if valor < raiz.valor:
        raiz.iz = insertar(raiz.iz, valor)
    else:
        raiz.der = insertar(raiz.der,valor)

    return raiz


#ejemplo construir este arbol :

raiz = None
raiz = insertar(raiz,10)
raiz = insertar(raiz,5)
raiz = insertar(raiz,15)
raiz = insertar(raiz,3)


print(f"raiz:{raiz.valor}")

print(f"izquierda nodo:{raiz.iz.valor}")
print(f"derecha nodo:{raiz.der.valor}")
print(f"izquierda de izquierda:{raiz.iz.iz.valor}")
# Out:
# raiz:10
# izquierda nodo:5
# derecha nodo:15
# izquierda de izquierda:3

# %%
#desafio n4
#insertar los valores 25,8,30,6 en ese orden
# en un arbol vacio en ese orde

def insertar(raiz,valor):
    if raiz is None:
        return  Nodo(valor)
    # si el valor es menor
    if valor < raiz.valor:
        raiz.iz = insertar(raiz.iz, valor)
    else:
        raiz.der = insertar(raiz.der,valor)

    return raiz


#ejemplo construir este arbol :

raiz = None
raiz = insertar(raiz,25)
raiz = insertar(raiz,8)
raiz = insertar(raiz,30)
raiz = insertar(raiz,6)


print(f"raiz:{raiz.valor}")

print(f"izquierda nodo:{raiz.iz.valor}")
print(f"derecha nodo:{raiz.der.valor}")
print(f"izquierda de izquierda:{raiz.iz.iz.valor}")
# Out:
# raiz:25
# izquierda nodo:8
# derecha nodo:30
# izquierda de izquierda:6

# %%
class Nodo:
    def __init__(self, valor):
        self.valor = valor
        self.izquierda = None 
        self.derecha = None


"""
Regla:
- Si es menor el valor - Exito
- Si es menor se busca en la izquierda
- Si es mayor se busca en la derecha
- Si llegas None es que no existe
"""

def buscar(raiz, valor):
    # si el arbol esta vacio
    if raiz is None:
     return raiz
    if raiz.valor == valor:
       return True
    if valor < raiz.valor:
       return buscar(raiz.izquierda, valor)
    return buscar(raiz.derecha, valor)

raiz = None
for valor in [10,5,15,3,7]:
   raiz = insertar(raiz, valor)

# buscar valores
print(f"Estara el 7: {buscar(raiz,7)}")
print(f"Estara el 20: {buscar(raiz,20)}")
print(f"Estara el 3: {buscar(raiz,3)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 28
#      26 raiz = None
#      27 for valor in [10,5,15,3,7]:
# ---> 28    raiz = insertar(raiz, valor)
#      30 # buscar valores
#      31 print(f"Estara el 7: {buscar(raiz,7)}")
#
# NameError: name 'insertar' is not defined

# %%
# Desafio 5:
#crear un arbol con [50.30.70.20.40]
# y busca si eciste el 40 y el 60
raiz = None
for valor in [50, 30, 70,20,40]:
    raiz = insertar(raiz, valor)

print(f"Estara el valor 40??: {buscar(raiz, 40)} ")
print(f"Estara el valor 60??: {buscar(raiz, 60)} ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 6
#       4 raiz = None
#       5 for valor in [50, 30, 70,20,40]:
# ----> 6     raiz = insertar(raiz, valor)
#       8 print(f"Estara el valor 40??: {buscar(raiz, 40)} ")
#       9 print(f"Estara el valor 60??: {buscar(raiz, 60)} ")
#
# NameError: name 'insertar' is not defined
